# %% [markdown]
# # Pt fits with Jupyter Notebooks
# This is a new attempt to fitting with Python

# %%
import matplotlib.pyplot as plt
import uproot
import numpy as np
import pandas as pd
import sklearn

# %%
fileData  = uproot.open("../AnalysisResultsNewLHC16s_noZDC.root") 
fileData2 = uproot.open("../AnalysisResultsNewLHC16s_noZDC.root") ["MyTask/MyOutputContainer"]

# %%
# fileData["MyTask/MyOutputContainer"]
fileData2
# Out:
# [<b'TH1F' b'fNumberMuonsH' 0x000a29a33d10>,
#  <b'TH1F' b'fCounterH' 0x000a29a1e2f0>,
#  <b'TH1F' b'fEtaMuonH' 0x000a29a1e590>,
#  <b'TH1F' b'fEtaDimuonH' 0x000a29a1e830>,
#  <b'TH1F' b'fRAbsMuonH' 0x000a29a1ead0>,
#  <b'TH1F' b'fInvariantMassDistributionH' 0x000a29a1ed70>,
#  <b'TH1F' b'fInvariantMassDistributionRapidityBinsNewH_0' 0x000a29a3a050>,
#  <b'TH1F' b'fInvariantMassDistributionRapidityBinsNewH_1' 0x000a29a3a2f0>,
#  <b'TH1F' b'fInvariantMassDistributionHCMUP3' 0x000a29a3a590>,
#  <b'TH1F' b'fInvariantMassDistributionHCMUP8' 0x000a29a3a830>,
#  <b'TH1F' b'fInvariantMassDistributionHCMUP14' 0x000a29a3aad0>,
#  <b'TH1F' b'fInvariantMassDistributionHCMUP15' 0x000a29a3ad70>,
#  <b'TH1F' b'fInvariantMassDistributionHCMUP16' 0x000a2a2ba050>,
#  <b'TH1F' b'fInvariantMassDistributionHCMUP17' 0x000a2a2ba2f0>,
#  <b'TH1F' b'fInvariantMassDistributionHCMUP18' 0x000a2a2ba590>,
#  <b'TH1F' b'fInvariantMassDistributionHCMUP19' 0x000a2a2ba830>,
# ...

# %%
for i in [0,1]:
    DataPt = [fileData["MyTask/MyOutputContainer/fDimuonPtDistributionZeroZNCbinsH_'{}'.format{i}"]]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-d0484ff2d5ad> in <module>
#       1 for i in [0,1]:
# ----> 2     DataPt = [fileData["MyTask/MyOutputContainer/fDimuonPtDistributionZeroZNCbinsH_'{}'.format{i}"]]
#
# ~/.local/lib/python3.7/site-packages/uproot/rootio.py in __getitem__(self, name)
#     222
#     223     def __getitem__(self, name):
# --> 224         return self.get(name)
#     225
#     226     def __len__(self):
#
# ~/.local/lib/python3.7/site-packages/uproot/rootio.py in get(self, name, cycle)
#     320             out = self
#     321             for n in name.split(b"/"):
# --> 322                 out = out.get(n, cycle)
#     323             return out
#     324
#
# AttributeError: 'TList' object has no attribute 'get'

# %%
index = [0,1]
for i in enumerate(index):
    DataPt = [fileData2["fDimuonPtDistributionZeroZNCbinsH_{:d}".format(i)]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-d60bb017ea99> in <module>
#       1 index = [0,1]
#       2 for i in enumerate(index):
# ----> 3     DataPt = [fileData2["fDimuonPtDistributionZeroZNCbinsH_{:d}".format(i)]]
#
# TypeError: unsupported format string passed to tuple.__format__

# %%
    DataPt2 = fileData2["fDimuonPtDistributionZeroZNCbinsH_0"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-32faa7f0a270> in <module>
# ----> 1 DataPt2 = fileData2["fDimuonPtDistributionZeroZNCbinsH_0"]
#
# TypeError: list indices must be integers or slices, not str

# %%
fileData2("fDimuonPtDistributionZeroZNCbinsH_0")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-7f9061d2f73c> in <module>
# ----> 1 fileData2("fDimuonPtDistributionZeroZNCbinsH_0")
#
# TypeError: 'TList' object is not callable

# %%
fileData2
# Out:
# [<b'TH1F' b'fNumberMuonsH' 0x000a29a33d10>,
#  <b'TH1F' b'fCounterH' 0x000a29a1e2f0>,
#  <b'TH1F' b'fEtaMuonH' 0x000a29a1e590>,
#  <b'TH1F' b'fEtaDimuonH' 0x000a29a1e830>,
#  <b'TH1F' b'fRAbsMuonH' 0x000a29a1ead0>,
#  <b'TH1F' b'fInvariantMassDistributionH' 0x000a29a1ed70>,
#  <b'TH1F' b'fInvariantMassDistributionRapidityBinsNewH_0' 0x000a29a3a050>,
#  <b'TH1F' b'fInvariantMassDistributionRapidityBinsNewH_1' 0x000a29a3a2f0>,
#  <b'TH1F' b'fInvariantMassDistributionHCMUP3' 0x000a29a3a590>,
#  <b'TH1F' b'fInvariantMassDistributionHCMUP8' 0x000a29a3a830>,
#  <b'TH1F' b'fInvariantMassDistributionHCMUP14' 0x000a29a3aad0>,
#  <b'TH1F' b'fInvariantMassDistributionHCMUP15' 0x000a29a3ad70>,
#  <b'TH1F' b'fInvariantMassDistributionHCMUP16' 0x000a2a2ba050>,
#  <b'TH1F' b'fInvariantMassDistributionHCMUP17' 0x000a2a2ba2f0>,
#  <b'TH1F' b'fInvariantMassDistributionHCMUP18' 0x000a2a2ba590>,
#  <b'TH1F' b'fInvariantMassDistributionHCMUP19' 0x000a2a2ba830>,
# ...

# %%
fileData2[2].Draw()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-ee3a75a52925> in <module>
# ----> 1 fileData2[2].Draw()
#
# AttributeError: 'TH1F' object has no attribute 'Draw'
